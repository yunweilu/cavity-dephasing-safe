# %%
import os
import sys
from helper.paths import simulation_dir

# After `pip install -e .`, locate this simulation folder from the clone
# (works when the Jupyter cwd is the repo root or any subdirectory).
_SIM_DIR = simulation_dir("preparation_fidelity")
os.chdir(_SIM_DIR)
sys.path.insert(0, str(_SIM_DIR))
print("Working directory:", os.getcwd())

import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import colorednoise as cn
import qutip as qt
from noise_generator import GenerateNoise
from hamiltonian_generator import Hamiltonian
from system import *
from joblib import Parallel, delayed
from scipy.optimize import curve_fit
# Out:
# Working directory: /Users/yunwei/Desktop/project/cavity dephasing/SAFE/simulations/preparation_fidelity

# %%
class Simulation:
    def __init__(self, A, initial_state, t_max, sample_rate, num_realizations, S0):
        self.A = A
        self.initial_state = initial_state
        
        # System parameters
        self.phi_ex = 0.2
        self.Ej = 30.19 
        self.Ec = 0.1

        # Setup Hamiltonian for optimal frequency calculation
        self.sc = Hamiltonian(self.phi_ex, self.Ej, self.Ec, [10,6])
        self.optimal_omega,rate = self.sc.optimal_omegad(self.A)
        self.optimal_omega = self.optimal_omega*2*np.pi
        self.sc = Hamiltonian(self.phi_ex, self.Ej, self.Ec, [3,2]) 
        self.sample_rate = sample_rate
        self.num_realizations = num_realizations
        self.S0 = S0
        self.t_max = t_max
        self.cplus_state, self.kick_and_sigmax, self.get_projector = self.sc.setup_floquet_system(A,self.optimal_omega)
        self.detuning = np.real(self.sc.H)[2,2] - self.optimal_omega

    def noise_check(self, if_plot=False):
        # Initialize arrays to store results
        tnoise_max = int(self.t_max)             # number of samples
        relative_PSD_strength = self.S0**2
        ifwhite = False               # True for white noise, False for 1/f noise
        
        gn = GenerateNoise(self.sample_rate, tnoise_max, relative_PSD_strength, self.num_realizations, ifwhite)
        trajs = gn.generate_colored_noise()
        self.trajs = trajs
        if if_plot:
            gn.analyze_noise_psd(trajs)
    
    def operators(self):
        sds = self.sc.noise
        sop = self.sc.s
        H_control = self.sc.H_control
        H0 = self.sc.H
        diagonal_energies = np.diag(self.sc.H) - self.sc.H[0,0]
        H0 = np.diag(diagonal_energies)
        sds = qt.Qobj(sds)
        sop = qt.Qobj(sop)
        H_control = qt.Qobj(H_control)
        H0 = qt.Qobj(H0)
        return sds, sop, H_control, H0,

    def I_control(self, ramp_time, T, amplitude=1.0):
        if ramp_time <= 0 or T < 2 * ramp_time:
            raise ValueError("Invalid parameters: Ensure ramp_time > 0 and T >= 2 * ramp_time")

        def pulse(t):
            t = np.asarray(t)
            result = np.zeros_like(t, dtype=float)

            # Sin-squared ramp up
            mask1 = (t > 0) & (t < ramp_time)
            result[mask1] = amplitude * np.sin((np.pi / 2) * (t[mask1] / ramp_time))**2

            # Flat top
            mask2 = (t >= ramp_time) & (t <= T - ramp_time)
            result[mask2] = amplitude

            # Sin-squared ramp down
            mask3 = (t > T - ramp_time) & (t < T)
            result[mask3] = amplitude * np.sin((np.pi / 2) * (1 - (t[mask3] - (T - ramp_time)) / ramp_time))**2

            if result.shape == ():
                return float(result)
            return result

        return pulse

    def Q_control(self, freq, ramp_time, T, amplitude=1.0):
        if ramp_time <= 0 or T < 2 * ramp_time:
            raise ValueError("Invalid parameters: Ensure ramp_time > 0 and T >= 2 * ramp_time")

        peak = amplitude * np.pi / (2 * ramp_time)

        def pulse_derivative(t):
            t = np.asarray(t)
            result = np.zeros_like(t, dtype=float)

            # Derivative of ramp up
            mask1 = (t > 0) & (t < ramp_time)
            result[mask1] = peak * np.sin(np.pi * t[mask1] / ramp_time)

            # Derivative of ramp down
            mask3 = (t > T - ramp_time) & (t < T)
            result[mask3] = -peak * np.sin(np.pi * (t[mask3] - (T - ramp_time)) / ramp_time)

            result = -result / freq

            if result.shape == ():
                return float(result)
            return result

        return pulse_derivative

    import numpy as np

    def A_function(self, freq, ramp_time, T, amplitude=1.0):
        if ramp_time <= 0 or T < 2 * ramp_time:
            raise ValueError("Invalid parameters: Ensure ramp_time > 0 and T >= 2 * ramp_time")

        deriv_peak = amplitude * np.pi / (2 * ramp_time)
        pi_over_2 = np.pi / 2
        pi_over_rt = np.pi / ramp_time
        inv_freq = 1.0 / freq

        def A(t):
            t = np.asarray(t, dtype=float)
            result = np.full_like(t, fill_value=0.0, dtype=float)

            # Use boolean masks once
            mask1 = (t > 0) & (t < ramp_time)
            mask2 = (t >= ramp_time) & (t <= T - ramp_time)
            mask3 = (t > T - ramp_time) & (t < T)

            # Ramp up calculations
            if np.any(mask1):
                ang1 = pi_over_2 * (t[mask1] / ramp_time)
                sin_ang1 = np.sin(ang1)
                I1 = amplitude * sin_ang1 * sin_ang1
                Q1 = -deriv_peak * np.sin(pi_over_rt * t[mask1]) * inv_freq
                result[mask1] = np.hypot(I1, Q1)  # More efficient for sqrt(I^2+Q^2)

            # Flat top amplitude is constant
            if np.any(mask2):
                result[mask2] = amplitude

            # Ramp down calculations
            if np.any(mask3):
                ang3 = pi_over_2 * (1 - (t[mask3] - (T - ramp_time)) / ramp_time)
                sin_ang3 = np.sin(ang3)
                I3 = amplitude * sin_ang3 * sin_ang3
                Q3 = deriv_peak * np.sin(pi_over_rt * (t[mask3] - (T - ramp_time))) * inv_freq
                result[mask3] = np.hypot(I3, Q3)

            if result.shape == ():
                return float(result)
            return result

        return A


    def phi_function(self, freq, ramp_time, T, amplitude=1.0):
        if ramp_time <= 0 or T < 2 * ramp_time:
            raise ValueError("Invalid parameters: Ensure ramp_time > 0 and T >= 2 * ramp_time")

        deriv_peak = amplitude * np.pi / (2 * ramp_time)
        pi_over_2 = np.pi / 2
        pi_over_rt = np.pi / ramp_time
        inv_freq = 1.0 / freq

        def phi(t):
            t = np.asarray(t, dtype=float)
            result = np.zeros_like(t, dtype=float)

            mask1 = (t > 0) & (t < ramp_time)
            mask2 = (t >= ramp_time) & (t <= T - ramp_time)
            mask3 = (t > T - ramp_time) & (t < T)

            # Ramp up phase
            if np.any(mask1):
                ang1 = pi_over_2 * (t[mask1] / ramp_time)
                sin_ang1 = np.sin(ang1)
                I1 = amplitude * sin_ang1 * sin_ang1
                Q1 = -deriv_peak * np.sin(pi_over_rt * t[mask1]) * inv_freq
                result[mask1] = np.arctan2(Q1, I1)

            # Plateau phase
            if np.any(mask2):
                result[mask2] = 0.0

            # Ramp down phase
            if np.any(mask3):
                ang3 = pi_over_2 * (1 - (t[mask3] - (T - ramp_time)) / ramp_time)
                sin_ang3 = np.sin(ang3)
                I3 = amplitude * sin_ang3 * sin_ang3
                Q3 = deriv_peak * np.sin(pi_over_rt * (t[mask3] - (T - ramp_time))) * inv_freq
                result[mask3] = np.arctan2(Q3, I3)

            if result.shape == ():
                return float(result)
            return result

        return phi

# %%
import numpy as np

def bootstrap_mean_and_std_error(data, num_samples=1000):
    """
    Calculates the bootstrap mean and the bootstrap standard error of the mean.

    Args:
        data (array-like): A list or NumPy array of your data points (e.g., 100 fidelities).
        num_samples (int): The number of bootstrap samples to generate.

    Returns:
        tuple: A tuple containing (bootstrap_mean, bootstrap_standard_error).
    """
    n_observations = len(data)
    bootstrap_means = []
    
    for _ in range(num_samples):
        # Create a bootstrap sample by sampling with replacement
        resample = np.random.choice(data, size=n_observations, replace=True)
        
        # Calculate the mean of the bootstrap sample and store it
        bootstrap_means.append(np.mean(resample))
        
    # The bootstrap estimate of the mean is the average of the bootstrap means
    bootstrap_mean_estimate = np.mean(bootstrap_means)
    
    # The bootstrap estimate of the standard error is the standard deviation of the bootstrap means
    bootstrap_std_error_estimate = np.std(bootstrap_means, ddof=1)
    
    return bootstrap_mean_estimate, bootstrap_std_error_estimate

# %%
# Define parameter ranges
ramp_times = [40, 80, 120, 160, 210]
A_values = [1e-3*2*np.pi, 2.5e-3*2*np.pi, 5e-3*2*np.pi]

def compute_fidelity_drag(ramp_time, A):

    initial_state = []
    t_max = 100000
    num_realizations = 100
    S0 = 1e-5
    sample_rate = 1        # per ns
    sim = Simulation(A,initial_state, t_max,sample_rate, num_realizations,S0)
    sim.noise_check()
    # Setup parameters
    time_points = np.linspace(0, ramp_time, 1000)
    T = 5 * ramp_time
    gamma = 0
    # Solver options and collapse operators
    opts = {'nsteps': sim.t_max, 'atol': 1e-12, 'rtol': 1e-12}
    
    # Get operators and functions
    sds, sop, H_control, H0 = sim.operators()
    c_ops = [np.sqrt(gamma) * qt.Qobj(sop)]
    freq = np.abs(np.real(H0.full())[2,2] - sim.optimal_omega)
    A_func = sim.A_function(freq, ramp_time, T, sim.A)
    phi_func = sim.phi_function(freq, ramp_time, T, sim.A)

    # Get Floquet states and projectors
    floquet_states, sigmax, sigmas = sim.kick_and_sigmax(ramp_time)
    projectors = sim.get_projector(floquet_states)

    # Define Hamiltonian terms
    drive_term = lambda t, args: A_func(t) * np.cos(sim.optimal_omega * t + phi_func(t))

    # Run simulations for both initial states
    avg_values = []
    values = []
    for idx in [0, 1]:
        def run_single_trajectory(traj_idx):
            traj = np.cos(sim.phi_ex*np.pi)*(np.cos(sim.trajs[traj_idx]*np.pi)-1) - np.sin(sim.phi_ex*np.pi)*np.sin(sim.trajs[traj_idx]*np.pi)
            noise_term = lambda t, args: traj[int(t * sim.sample_rate)] if t < sim.t_max else 0
            H = [H0, [sds, noise_term], [H_control, drive_term]]
            result = qt.mesolve(H, qt.basis(6, idx), time_points, c_ops, options=opts)
            return result.states[-1]
        
        # Parallelize over all trajectories using joblib
        from joblib import Parallel, delayed
        final_states = Parallel(n_jobs=-1)(delayed(run_single_trajectory)(traj_idx) for traj_idx in range(sim.num_realizations))
        
        # Compute expectation values for each final state
        values.append([qt.expect(projectors[idx], state) for state in final_states])
        # Compute average final state
        final_state = sum(final_states) / len(final_states)
        
        avg_values.append(qt.expect(projectors[idx], final_state))
    avg_value0, avg_value1 = avg_values
    # Compute fidelity for each trajectory
    fidelities = []
    for traj_idx in range(sim.num_realizations):
        value0 = values[0][traj_idx]
        value1 = values[1][traj_idx]
        fidelity = (np.sqrt(value0) + np.sqrt(value1))**2/4
        fidelities.append(fidelity)
    # Compute infidelity for each trajectory
    infidelities = 1 - np.array(fidelities)
    mean_infid, std_error_infid = bootstrap_mean_and_std_error(infidelities, num_samples=10000)
    return mean_infid, std_error_infid

def compute_fidelity(ramp_time, A):
    initial_state = []
    t_max = 100000
    num_realizations = 100
    S0 = 1e-5
    sample_rate = 1        # per ns
    sim = Simulation(A,initial_state, t_max,sample_rate, num_realizations,S0)
    sim.noise_check()
    # Setup parameters
    time_points = np.linspace(0, ramp_time, 1000)
    T = 5 * ramp_time
    gamma = 1 / (2e4)

    # Get operators and functions
    sds, sop, H_control, H0 = sim.operators()
    freq = np.abs(np.real(H0.full())[2,2] - sim.optimal_omega)
    A_func = sim.I_control(ramp_time, T, A)

    # Get Floquet states and projectors
    floquet_states, sigmax, sigmas = sim.kick_and_sigmax(ramp_time)
    projectors = sim.get_projector(floquet_states)

    # Define Hamiltonian terms
    drive_term = lambda t, args: A_func(t) * np.cos(sim.optimal_omega * t)

    # Solver options and collapse operators
    opts = {'nsteps': sim.t_max, 'atol': 1e-12, 'rtol': 1e-12}
    c_ops = [np.sqrt(gamma) * qt.Qobj(sop)]

    # Run simulations for both initial states
    avg_values = []
    values = []
    for idx in [0, 1]:
        def run_single_trajectory(traj_idx):
            traj = np.cos(sim.phi_ex*np.pi)*(np.cos(sim.trajs[traj_idx]*np.pi)-1) - np.sin(sim.phi_ex*np.pi)*np.sin(sim.trajs[traj_idx]*np.pi)
            noise_term = lambda t, args: traj[int(t * sim.sample_rate)] if t < sim.t_max else 0
            H = [H0, [sds, noise_term], [H_control, drive_term]]
            result = qt.mesolve(H, qt.basis(6, idx), time_points, c_ops, options=opts)
            return result.states[-1]
        
        # Parallelize over all trajectories using joblib
        from joblib import Parallel, delayed
        final_states = Parallel(n_jobs=-1)(delayed(run_single_trajectory)(traj_idx) for traj_idx in range(sim.num_realizations))
        
        # Compute expectation values for each final state
        values.append([qt.expect(projectors[idx], state) for state in final_states])
        # Compute average final state
        final_state = sum(final_states) / len(final_states)
        
        avg_values.append(qt.expect(projectors[idx], final_state))
    avg_value0, avg_value1 = avg_values
    # Compute fidelity for each trajectory
    fidelities = []
    for traj_idx in range(sim.num_realizations):
        value0 = values[0][traj_idx]
        value1 = values[1][traj_idx]
        fidelity = (np.sqrt(value0) + np.sqrt(value1))**2/4
        fidelities.append(fidelity)
    # Compute infidelity for each trajectory
    infidelities = 1 - np.array(fidelities)
    mean_infid, std_error_infid = bootstrap_mean_and_std_error(infidelities, num_samples=10000)
    return mean_infid, std_error_infid

# %%
# Run for loop for different ramp_time and A values
results = []
std_errors = []
for ramp_time in ramp_times:
    for A in A_values:
        avg, std = compute_fidelity_drag(ramp_time, A)
        results.append(avg)
        std_errors.append(std)
        print(f"Ramp time: {ramp_time}, A: {A/(2*np.pi):.3e}, Infidelity: {avg:.6e} ± {std:.6e}")

# Create infidelity matrix and std error matrix
infidelity_matrix = np.array(results).reshape(len(ramp_times), len(A_values))
std_error_matrix = np.array(std_errors).reshape(len(ramp_times), len(A_values))

print(f"\nRamp times: {ramp_times}")
print(f"A values: {[A/(2*np.pi) for A in A_values]}")
print(f"Infidelity matrix shape: {infidelity_matrix.shape}")
print(f"Infidelity matrix:\n{infidelity_matrix}")
print(f"Std error matrix:\n{std_error_matrix}")
# Out:
# original_rate (omega_s) = 3.439818e+02, min_rate = 5.314860e-06
# optimal_omega_d = 6.165443 GHz, detuning = 6.3539 MHz
# capi_return is NULL
# Call-back cb_f_in_zvode__user__routines failed.
# Fatal Python error: F2PySwapThreadLocalCallbackPtr: F2PySwapThreadLocalCallbackPtr: PyLong_AsVoidPtr failed
# Python runtime state: initialized
# capi_return is NULL
# Call-back cb_f_in_zvode__user__routines failed.
# capi_return is NULL
# capi_return is NULL
# Call-back cb_f_in_zvode__user__routines failed.
# Call-back cb_f_in_zvode__user__routines failed.
# capi_return is NULL
# Call-back cb_f_in_zvode__user__routines failed.
# Fatal Python error: F2PySwapThreadLocalCallbackPtrFatal Python error: : F2PySwapThreadLocalCallbackPtrF2PySwapThreadLocalCallbackPtr: PyLong_AsVoidPtr failed: F2PySwapThreadLocalCallbackPtr: PyLong_AsVoidPtr failed
# Python runtime state: initialized
# capi_return is NULL
# Fatal Python error: Call-back cb_f_in_zvode__user__routines failed.
# F2PySwapThreadLocalCallbackPtr: capi_return is NULL
# F2PySwapThreadLocalCallbackPtr: PyLong_AsVoidPtr failed
# Fatal Python error: Python runtime state: F2PySwapThreadLocalCallbackPtrinitialized: Fatal Python error:
# F2PySwapThreadLocalCallbackPtr: F2PySwapThreadLocalCallbackPtr: PyLong_AsVoidPtr failed
# Python runtime state: initialized
# Traceback (most recent call last):
# capi_return is NULL
# Call-back cb_f_in_zvode__user__routines failed.
# Traceback (most recent call last):
# Traceback (most recent call last):
# Fatal Python error: Traceback (most recent call last):
# F2PySwapThreadLocalCallbackPtr  File "/opt/homebrew/Caskroom/miniconda/base/envs/fluxonium/lib/python3.11/site-packages/qutip/solver/integrator/scipy_integrator.py", line 69, in _mul_np_vec
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/fluxonium/lib/python3.11/site-packages/qutip/solver/integrator/scipy_integrator.py", line 69, in _mul_np_vec
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/fluxonium/lib/python3.11/site-packages/qutip/solver/integrator/scipy_integrator.py", line 69, in _mul_np_vec
# F2PySwapThreadLocalCallbackPtr: PyLong_AsVoidPtr failed
# Call-back cb_f_in_zvode__user__routines failed.
# : F2PySwapThreadLocalCallbackPtr: PyLong_AsVoidPtr failed
# Python runtime state: initialized
# Python runtime state: Fatal Python error: initializedF2PySwapThreadLocalCallbackPtr
# : F2PySwapThreadLocalCallbackPtr: PyLong_AsVoidPtr failed
# Python runtime state: initialized
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/fluxonium/lib/python3.11/site-packages/qutip/solver/integrator/scipy_integrator.py", line 69, in _mul_np_vec
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/fluxonium/lib/python3.11/site-packages/qutip/solver/integrator/scipy_integrator.py", line 69, in _mul_np_vec
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/fluxonium/lib/python3.11/site-packages/qutip/solver/integrator/scipy_integrator.py", line 69, in _mul_np_vec
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/fluxonium/lib/python3.11/site-packages/qutip/solver/integrator/scipy_integrator.py", line 69, in _mul_np_vec
#
# Python runtime state: initialized
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/fluxonium/lib/python3.11/site-packages/qutip/solver/integrator/scipy_integrator.py", line 69, in _mul_np_vec
#         out = self.system.matmul_data(t, state)out = self.system.matmul_data(t, state)
#
#     out = self.system.matmul_data(t, state)
#     out = self.system.matmul_data(t, state)
#                     ^^^^^^^^^                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^    ^out = self.system.matmul_data(t, state)^
#     out = self.system.matmul_data(t, state)        ^out = self.system.matmul_data(t, state)
# ^^^^^^^^^^^^
# ^^^^^^^^^^^^^out = self.system.matmul_data(t, state)
#
#      File "qutip/core/cy/qobjevo.pyx", line 1105, in qutip.core.cy.qobjevo.QobjEvo.matmul_data
#       ^    ^^^^^^^  ^    ^^^^^^^^^^^^^^^^^^  ^   ^^^^^^
# ^^ ^^^ ^^^   File "qutip/core/cy/qobjevo.pyx", line 1105, in qutip.core.cy.qobjevo.QobjEvo.matmul_data
#    File "qutip/core/cy/qobjevo.pyx", line 1117, in qutip.core.cy.qobjevo.QobjEvo.matmul_data
#   ^^^ ^^^^^^^^^^  File "qutip/core/cy/_element.pyx", line 167, in qutip.core.cy._element._BaseElement.matmul_data_t
# ^^^^^^^^^^^^^
# ^^^^^  File "qutip/core/cy/qobjevo.pyx", line 1105, in qutip.core.cy.qobjevo.QobjEvo.matmul_data
# ^^^^^^^^^^^^^^^ ^^^^^^ ^ ^   File "qutip/core/cy/_element.pyx", line 367, in qutip.core.cy._element._EvoElement.coeff
#  ^    ^^^^^^^^^^  File "qutip/core/cy/coefficient.pyx", line 220, in qutip.core.cy.coefficient.FunctionCoefficient.__call__
# ^^^^^^  File "qutip/core/cy/qobjevo.pyx", line 1117, in qutip.core.cy.qobjevo.QobjEvo.matmul_data
# ^^^^^^^^^^^^^^^^^^  File "qutip/core/cy/qobjevo.pyx", line 1117, in qutip.core.cy.qobjevo.QobjEvo.matmul_data
# ^  File "/var/folders/nt/998zzxpj2632htnn_h4jz6n40000gn/T/ipykernel_4328/3311661537.py", line 33, in <lambda>
# ^^^^^^^^^
# ^^^^^^^  File "qutip/core/cy/qobjevo.pyx", line 1105, in qutip.core.cy.qobjevo.QobjEvo.matmul_data
# ^^^^
# ^^^^  File "qutip/core/cy/_element.pyx", line 167, in qutip.core.cy._element._BaseElement.matmul_data_t
# ^^^^^
# ^^^^^  File "qutip/core/cy/qobjevo.pyx", line 1105, in qutip.core.cy.qobjevo.QobjEvo.matmul_data
# ^^^^^^  File "qutip/core/cy/_element.pyx", line 167, in qutip.core.cy._element._BaseElement.matmul_data_t
# ^  File "qutip/core/cy/qobjevo.pyx", line 1105, in qutip.core.cy.qobjevo.QobjEvo.matmul_data
#   File "qutip/core/cy/_element.pyx", line 367, in qutip.core.cy._element._EvoElement.coeff
# ^
# ^^  File "qutip/core/cy/qobjevo.pyx", line 1117, in qutip.core.cy.qobjevo.QobjEvo.matmul_data
#   File "qutip/core/cy/coefficient.pyx", line 220, in qutip.core.cy.coefficient.FunctionCoefficient.__call__
#   File "qutip/core/cy/qobjevo.pyx", line 1105, in qutip.core.cy.qobjevo.QobjEvo.matmul_data
#   File "qutip/core/cy/qobjevo.pyx", line 1117, in qutip.core.cy.qobjevo.QobjEvo.matmul_data
#   File "/var/folders/nt/998zzxpj2632htnn_h4jz6n40000gn/T/ipykernel_4328/3311661537.py", line 33, in <lambda>
#   File "/var/folders/nt/998zzxpj2632htnn_h4jz6n40000gn/T/ipykernel_4328/4047793005.py", line 121, in A
#   File "qutip/core/cy/_element.pyx", line 167, in qutip.core.cy._element._BaseElement.matmul_data_t
#   File "qutip/core/cy/_element.pyx", line 367, in qutip.core.cy._element._EvoElement.coeff
#   File "qutip/core/cy/qobjevo.pyx", line 1117, in qutip.core.cy.qobjevo.QobjEvo.matmul_data
#   File "/var/folders/nt/998zzxpj2632htnn_h4jz6n40000gn/T/ipykernel_4328/4047793005.py", line 125, in A
# ^  File "qutip/core/cy/_element.pyx", line 367, in qutip.core.cy._element._EvoElement.coeff
# ^^^^^^^^^^^^
# KeyboardInterrupt  File "qutip/core/cy/qobjevo.pyx", line 1105, in qutip.core.cy.qobjevo.QobjEvo.matmul_data
#
#   File "qutip/core/cy/qobjevo.pyx", line 1117, in qutip.core.cy.qobjevo.QobjEvo.matmul_data
# KeyboardInterrupt
#   File "qutip/core/cy/_element.pyx", line 167, in qutip.core.cy._element._BaseElement.matmul_data_t
#   File "qutip/core/cy/_element.pyx", line 167, in qutip.core.cy._element._BaseElement.matmul_data_t
#   File "qutip/core/cy/coefficient.pyx", line 220, in qutip.core.cy.coefficient.FunctionCoefficient.__call__
#   File "qutip/core/cy/coefficient.pyx", line 220, in qutip.core.cy.coefficient.FunctionCoefficient.__call__
#   File "qutip/core/cy/_element.pyx", line 167, in qutip.core.cy._element._BaseElement.matmul_data_t
#   File "/var/folders/nt/998zzxpj2632htnn_h4jz6n40000gn/T/ipykernel_4328/3311661537.py", line 33, in <lambda>
#   File "qutip/core/cy/_element.pyx", line 367, in qutip.core.cy._element._EvoElement.coeff
#   File "qutip/core/cy/qobjevo.pyx", line 1117, in qutip.core.cy.qobjevo.QobjEvo.matmul_data
#   File "qutip/core/cy/_element.pyx", line 367, in qutip.core.cy._element._EvoElement.coeff
#   File "qutip/core/cy/_element.pyx", line 367, in qutip.core.cy._element._EvoElement.coeff
#   File "/var/folders/nt/998zzxpj2632htnn_h4jz6n40000gn/T/ipykernel_4328/3311661537.py", line 33, in <lambda>
#   File "/var/folders/nt/998zzxpj2632htnn_h4jz6n40000gn/T/ipykernel_4328/4047793005.py", line 158, in phi
#   File "qutip/core/cy/coefficient.pyx", line 220, in qutip.core.cy.coefficient.FunctionCoefficient.__call__
#   File "qutip/core/cy/coefficient.pyx", line 220, in qutip.core.cy.coefficient.FunctionCoefficient.__call__
#   File "qutip/core/cy/_element.pyx", line 167, in qutip.core.cy._element._BaseElement.matmul_data_t
#   File "qutip/core/cy/coefficient.pyx", line 220, in qutip.core.cy.coefficient.FunctionCoefficient.__call__
#
# Extension modules: numpy._core._multiarray_umath  File "/opt/homebrew/Caskroom/miniconda/base/envs/fluxonium/lib/python3.11/site-packages/numpy/_core/numeric.py", line 128, in zeros_like
# , numpy.linalg._umath_linalg  File "/var/folders/nt/998zzxpj2632htnn_h4jz6n40000gn/T/ipykernel_4328/4047793005.py", line 126, in A
#   File "/var/folders/nt/998zzxpj2632htnn_h4jz6n40000gn/T/ipykernel_4328/3311661537.py", line 33, in <lambda>
#   File "/var/folders/nt/998zzxpj2632htnn_h4jz6n40000gn/T/ipykernel_4328/3311661537.py", line 33, in <lambda>
#   File "qutip/core/cy/_element.pyx", line 367, in qutip.core.cy._element._EvoElement.coeff
#   File "/var/folders/nt/998zzxpj2632htnn_h4jz6n40000gn/T/ipykernel_4328/3311661537.py", line 33, in <lambda>
#
# Extension modules: numpy._core._multiarray_umath, psutil._psutil_osx, psutil._psutil_posix, numpy.linalg._umath_linalg  File "/var/folders/nt/998zzxpj2632htnn_h4jz6n40000gn/T/ipykernel_4328/4047793005.py", line 121, in A
# , PIL._imagingKeyboardInterrupt
# , kiwisolver._cext,   File "/var/folders/nt/998zzxpj2632htnn_h4jz6n40000gn/T/ipykernel_4328/4047793005.py", line 165, in phi
# psutil._psutil_osx, psutil._psutil_posix  File "/var/folders/nt/998zzxpj2632htnn_h4jz6n40000gn/T/ipykernel_4328/4047793005.py", line 125, in A
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/fluxonium/lib/python3.11/site-packages/numpy/_core/fromnumeric.py", line 2472, in _any_dispatcher
#   File "qutip/core/cy/coefficient.pyx", line 220, in qutip.core.cy.coefficient.FunctionCoefficient.__call__
# , PIL._imaging, scipy._lib._ccallback_c, kiwisolver._cext  File "/opt/homebrew/Caskroom/miniconda/base/envs/fluxonium/lib/python3.11/site-packages/numpy/_core/fromnumeric.py", line 2472, in _any_dispatcher
# KeyboardInterrupt
# , numpy.random._common  File "/var/folders/nt/998zzxpj2632htnn_h4jz6n40000gn/T/ipykernel_4328/3311661537.py", line 33, in <lambda>
# , numpy.random.bit_generator, numpy.random._bounded_integers, numpy.random._mt19937, numpy.random.mtrand, scipy._lib._ccallback_c, numpy.random._philox  File "/var/folders/nt/998zzxpj2632htnn_h4jz6n40000gn/T/ipykernel_4328/4047793005.py", line 125, in A
# , numpy.random._pcg64, numpy.random._sfc64, numpy.random._common, KeyboardInterrupt, numpy.random.bit_generatornumpy.random._generator
# , scipy.sparse._sparsetools, _csparsetools, scipy.sparse._csparsetools, , numpy.random._bounded_integersscipy.linalg._fblas, numpy.random._mt19937, scipy.linalg._flapack, scipy.linalg.cython_lapack, numpy.random.mtrand, , numpy.random._philoxscipy.linalg._cythonized_array_utils, scipy.linalg._solve_toeplitz, numpy.random._pcg64, scipy.linalg._decomp_lu_cython, scipy.linalg._matfuncs_sqrtm_triu, numpy.random._sfc64, scipy.linalg.cython_blas, scipy.linalg._matfuncs_expm, numpy.random._generator, scipy.linalg._decomp_update, scipy.sparse.linalg._dsolve._superlu, scipy.sparse.linalg._eigen.arpack._arpack, scipy.sparse._sparsetools, scipy.sparse.linalg._propack._spropack, _csparsetools, scipy.sparse.linalg._propack._dpropack, , scipy.sparse._csparsetoolsscipy.sparse.linalg._propack._cpropack, scipy.linalg._fblas
# Extension modules: numpy._core._multiarray_umath    , res = empty_like(scipy.linalg._flapack
# , scipy.sparse.linalg._propack._zpropack , numpy.linalg._umath_linalg      ,  scipy.linalg.cython_lapack, scipy.sparse.csgraph._tools , scipy.sparse.csgraph._shortest_path ^^^^^^, ^scipy.sparse.csgraph._traversal^^^^
# , scipy.sparse.csgraph._min_spanning_tree  File "/opt/homebrew/Caskroom/miniconda/base/envs/fluxonium/lib/python3.11/site-packages/numpy/_core/multiarray.py", line 107, in empty_like
# , psutil._psutil_osx, scipy.sparse.csgraph._flow, psutil._psutil_posix, scipy.sparse.csgraph._matching
# Extension modules: , scipy.sparse.csgraph._reordering, numpy._core._multiarray_umathscipy.linalg._cythonized_array_utils, , scipy.linalg._solve_toeplitz, PIL._imaging, scipy.linalg._decomp_lu_cythonscipy.spatial._ckdtree, scipy.linalg._matfuncs_sqrtm_triu, scipy.linalg.cython_blas, scipy._lib.messagestream, kiwisolver._cext, scipy.linalg._matfuncs_expm, scipy.spatial._qhull, scipy.linalg._decomp_update, scipy.spatial._voronoi, numpy.linalg._umath_linalg, scipy.sparse.linalg._dsolve._superlu, scipy.spatial._distance_wrap, scipy.sparse.linalg._eigen.arpack._arpack, scipy.spatial._hausdorff, scipy.sparse.linalg._propack._spropack, scipy.special._ufuncs_cxx, scipy.sparse.linalg._propack._dpropack, scipy.special._cdflib, scipy.sparse.linalg._propack._cpropack, scipy.special._ufuncs, scipy.sparse.linalg._propack._zpropack, scipy.special._specfun, scipy.sparse.csgraph._tools, scipy.special._comb, , scipy.sparse.csgraph._shortest_pathscipy._lib._ccallback_c, scipy.special._ellip_harm_2, scipy.sparse.csgraph._traversal, scipy.spatial.transform._rotation, numpy.random._common, , , scipy.ndimage._nd_imagescipy.sparse.csgraph._min_spanning_tree, _ni_label, scipy.sparse.csgraph._flow, , scipy.ndimage._ni_labelpsutil._psutil_osxnumpy.random.bit_generator, scipy.sparse.csgraph._matching, scipy.optimize._minpack2, scipy.sparse.csgraph._reordering, scipy.optimize._group_columns, , scipy.optimize._trlib._trlib, scipy.optimize._lbfgsb, psutil._psutil_posix, scipy.spatial._ckdtreenumpy.random._bounded_integers, _moduleTNC, , scipy._lib.messagestream, scipy.spatial._qhullnumpy.random._mt19937, scipy.optimize._moduleTNC, scipy.spatial._voronoi, scipy.optimize._cobyla, scipy.spatial._distance_wrap, numpy.random.mtrand, scipy.spatial._hausdorff, scipy.optimize._slsqp, scipy.special._ufuncs_cxx, numpy.random._philox, , scipy.special._cdflib, scipy.special._ufuncs, scipy.special._specfun, PIL._imaging, scipy.special._comb, numpy.random._pcg64, scipy.special._ellip_harm_2, numpy.random._sfc64, scipy.spatial.transform._rotation, numpy.random._generator, kiwisolver._cext, scipy.ndimage._nd_image, _ni_label, scipy.ndimage._ni_label, scipy.optimize._minpack2, scipy.sparse._sparsetools, scipy.optimize._group_columns, _csparsetools, scipy.optimize._trlib._trlib, scipy.sparse._csparsetools, scipy.optimize._lbfgsb, scipy._lib._ccallback_c, scipy.linalg._fblas, _moduleTNC, scipy.linalg._flapack, scipy.optimize._moduleTNC, , numpy.random._commonscipy.linalg.cython_lapack, scipy.optimize._cobyla, scipy.linalg._cythonized_array_utils, scipy.optimize._slsqp, numpy.random.bit_generator, scipy.linalg._solve_toeplitz, numpy.random._bounded_integersscipy.optimize._minpack, scipy.linalg._decomp_lu_cython, , numpy.random._mt19937scipy.optimize._minpack, scipy.linalg._matfuncs_sqrtm_triu
# Extension modules: numpy._core._multiarray_umath, numpy.random.mtrand, , scipy.linalg.cython_blasscipy.optimize._lsq.givens_elimination, numpy.random._philox, scipy.linalg._matfuncs_expm, scipy.optimize._lsq.givens_elimination, , , scipy.linalg._decomp_updatenumpy.random._pcg64, , scipy.sparse.linalg._dsolve._superlunumpy.linalg._umath_linalg, scipy.sparse.linalg._eigen.arpack._arpackscipy.optimize._zeros, scipy.sparse.linalg._propack._spropack, scipy.optimize._zeros, scipy.optimize._highs.cython.src._highs_wrapper, numpy.random._sfc64, , scipy.optimize._highs._highs_wrapperscipy.sparse.linalg._propack._dpropack, , scipy.optimize._highs.cython.src._highs_constants, numpy.random._generator, scipy.optimize._highs._highs_constantsscipy.optimize._highs.cython.src._highs_wrapper, scipy.linalg._interpolative, scipy.sparse.linalg._propack._cpropack, scipy.optimize._bglu_dense, scipy.optimize._highs._highs_wrapper, , scipy.sparse._sparsetoolspsutil._psutil_osx, scipy.optimize._lsap, _csparsetools, psutil._psutil_posix, scipy.optimize._direct, , , scipy.sparse._csparsetoolsscipy.integrate._odepack, scipy.sparse.linalg._propack._zpropackscipy.integrate._quadpack, , scipy.integrate._vode, scipy.integrate._dopscipy.optimize._highs.cython.src._highs_constants, , scipy.integrate._lsodascipy.linalg._fblas, , PIL._imagingscipy.optimize._highs._highs_constants, scipy.special.cython_special, scipy.linalg._interpolative, scipy.stats._stats, scipy.optimize._bglu_dense, scipy.stats.beta_ufunc, kiwisolver._cext, scipy.linalg._flapack, scipy.stats._boost.beta_ufunc, scipy.sparse.csgraph._tools, , scipy.optimize._lsapscipy.linalg.cython_lapack, scipy.stats.binom_ufunc, scipy.stats._boost.binom_ufunc, , scipy.sparse.csgraph._shortest_path, scipy.stats.nbinom_ufuncscipy.linalg._cythonized_array_utils, scipy.sparse.csgraph._traversal, scipy.stats._boost.nbinom_ufunc, , scipy.stats.hypergeom_ufuncscipy.optimize._direct, scipy.linalg._solve_toeplitz, scipy.sparse.csgraph._min_spanning_tree, scipy.stats._boost.hypergeom_ufunc, scipy.integrate._odepack, scipy.integrate._quadpack, , , scipy.integrate._vodescipy.linalg._decomp_lu_cython, scipy.integrate._dopscipy.stats.ncf_ufunc, scipy._lib._ccallback_c, scipy.integrate._lsoda, scipy.linalg._matfuncs_sqrtm_triu, , scipy.sparse.csgraph._flow, scipy.special.cython_special, scipy.stats._stats, scipy.sparse.csgraph._matchingscipy.stats._boost.ncf_ufunc, scipy.stats.beta_ufunc, scipy.sparse.csgraph._reordering, scipy.linalg.cython_blas, scipy.stats._boost.beta_ufunc, scipy.spatial._ckdtree, scipy.stats.ncx2_ufunc, scipy.stats.binom_ufunc, numpy.random._common, , , scipy._lib.messagestreamscipy.stats._boost.binom_ufunc, scipy.stats.nbinom_ufunc    , , scipy.stats._boost.nbinom_ufuncscipy.linalg._matfuncs_expmdef _any_dispatcher(a, axis=None, out=None, keepdims=None, *,
# , , scipy.stats._boost.ncx2_ufunc    , scipy.linalg._decomp_update def _any_dispatcher(a, axis=None, out=None, keepdims=None, *,,  scipy.stats.nct_ufunc scipy.spatial._qhull, scipy.stats.hypergeom_ufuncscipy.sparse.linalg._dsolve._superlu, , scipy.stats._boost.hypergeom_ufunc
# , , scipy.stats.ncf_ufuncscipy.sparse.linalg._eigen.arpack._arpack,  numpy.random.bit_generator,
# scipy.sparse.linalg._propack._spropackscipy.stats._boost.nct_ufunc,  , scipy.stats.skewnorm_ufunc, , scipy.stats._boost.skewnorm_ufuncKeyboardInterrupt     , @array_function_from_c_func_and_dispatcher(_multiarray_umath.empty_like)scipy.stats.invgauss_ufunc, scipy.stats._boost.ncf_ufuncnumpy.random._bounded_integers, ,  scipy.spatial._voronoi,
# ,
#  scipy.sparse.linalg._propack._dpropack
# scipy.stats._boost.invgauss_ufunc, ,  scipy.spatial._distance_wrap, scipy.interpolate._fitpackscipy.sparse.linalg._propack._cpropacknumpy.random._mt19937KeyboardInterrupt scipy.stats.ncx2_ufunc
#   ,
# , scipy.interpolate.dfitpack, scipy.sparse.linalg._propack._zpropack, scipy.spatial._hausdorffnumpy.random.mtrand, scipy.interpolate._bspl, scipy.sparse.csgraph._tools, , scipy.sparse.csgraph._shortest_pathscipy.special._ufuncs_cxx, , KeyboardInterruptscipy.stats._boost.ncx2_ufunc, scipy.interpolate._ppoly, scipy.special._cdflibnumpy.random._philox,
# , scipy.sparse.csgraph._traversalscipy.stats.nct_ufunc, , numpy.random._pcg64scipy.special._ufuncs, , , scipy.stats._boost.nct_ufunc, scipy.interpolate.interpnd, scipy.special._specfun, scipy.interpolate._rbfinterp_pythrannumpy.random._sfc64, scipy.sparse.csgraph._min_spanning_tree, , scipy.interpolate._rgi_cythonscipy.special._combscipy.stats.skewnorm_ufunc, , scipy.stats._boost.skewnorm_ufuncnumpy.random._generator, scipy.special._ellip_harm_2, scipy.stats.invgauss_ufunc, scipy.stats._biasedurn, scipy.stats._boost.invgauss_ufunc, scipy.interpolate._fitpack, scipy.spatial.transform._rotation, scipy.stats._levy_stable.levyst, scipy.interpolate.dfitpack, scipy.interpolate._bspl, , scipy.stats._stats_pythran, , , scipy._lib._uarray._uarrayscipy.interpolate._ppolyscipy.sparse._sparsetools, scipy.stats._ansari_swilk_statistics, scipy.interpolate.interpnd
# Extension modules: numpy._core._multiarray_umath, _csparsetools, scipy.stats._sobol, scipy.interpolate._rbfinterp_pythran, scipy.sparse._csparsetools, scipy.stats._qmc_cy, , scipy.interpolate._rgi_cythonnumpy.linalg._umath_linalg, scipy.linalg._fblas, scipy.stats._mvn, scipy.stats._biasedurn, scipy.linalg._flapackscipy.sparse.csgraph._flow, scipy.stats._levy_stable.levyst, scipy.linalg.cython_lapack, scipy.stats._stats_pythran, scipy.linalg._cythonized_array_utils, scipy._lib._uarray._uarray, scipy.linalg._solve_toeplitz,
# Extension modules: psutil._psutil_osxnumpy._core._multiarray_umath, scipy.sparse.csgraph._matching, , scipy.linalg._decomp_lu_cythonscipy.stats._ansari_swilk_statistics, scipy.ndimage._nd_image, numpy.linalg._umath_linalg, , , scipy.linalg._matfuncs_sqrtm_triuscipy.stats._sobolpsutil._psutil_posix, _ni_label, scipy.linalg.cython_blas, , scipy.stats._qmc_cy, scipy.ndimage._ni_labelscipy.sparse.csgraph._reordering, scipy.linalg._matfuncs_expm, scipy.stats._mvn, scipy.optimize._minpack2, scipy.optimize._group_columns, , scipy.linalg._decomp_update,
# Extension modules: scipy.optimize._trlib._trlib, PIL._imagingpsutil._psutil_osx, , scipy.optimize._lbfgsbnumpy._core._multiarray_umath, , scipy.stats._rcont.rcontscipy.stats._rcont.rcont, _moduleTNC, scipy.spatial._ckdtreescipy.sparse.linalg._dsolve._superlu, , scipy.optimize._moduleTNC, scipy.stats._unuran.unuran_wrapper, kiwisolver._cextscipy.stats._unuran.unuran_wrapper, , numpy.linalg._umath_linalgscipy.optimize._cobyla, psutil._psutil_posix, scipy.optimize._slsqp, scipy._lib.messagestream, , cython.cimports.libc.math, , cython.cimports.libc.mathscipy.optimize._minpack, scipy._lib._ccallback_c, scipy.spatial._qhull, qutip.core.data.base, qutip.core.data.base, scipy.spatial._voronoi, scipy.optimize._lsq.givens_elimination, , psutil._psutil_osxnumpy.random._common, PIL._imaging, qutip.core.data.convert, qutip.core.data.convert, scipy.spatial._distance_wrap, numpy.random.bit_generator, psutil._psutil_posix, scipy.optimize._zeros, , qutip.core.data.dispatchqutip.core.data.dispatchscipy.sparse.linalg._eigen.arpack._arpack, , qutip.core.data.adjoint, scipy.spatial._hausdorff, scipy.sparse.linalg._propack._spropack, scipy.optimize._highs.cython.src._highs_wrapper, , kiwisolver._cextqutip.core.data.adjoint, , PIL._imagingnumpy.random._bounded_integers, numpy.random._mt19937, , scipy.optimize._highs._highs_wrapperscipy.sparse.linalg._propack._dpropack, numpy.random.mtrand, scipy.special._ufuncs_cxx, qutip.core.data.reshape, numpy.random._philox, scipy.sparse.linalg._propack._cpropack, scipy.optimize._highs.cython.src._highs_constants, scipy.special._cdflib, numpy.random._pcg64, qutip.core.data.trace, kiwisolver._cext, scipy.sparse.linalg._propack._zpropack, , numpy.random._sfc64scipy.special._ufuncs, scipy.optimize._highs._highs_constants, numpy.random._generatorqutip.core.data.reshape, scipy.sparse.csgraph._tools, scipy.special._specfun, scipy._lib._ccallback_c, , scipy.linalg._interpolativescipy.sparse.csgraph._shortest_path, , scipy.special._comb, qutip.core.data.trace, , scipy.sparse.csgraph._traversalnumpy.random._common, , , , qutip.core.data.tidyupscipy.special._ellip_harm_2, qutip.core.data.tidyupscipy._lib._ccallback_c, numpy.random.bit_generator, scipy.spatial.transform._rotationscipy.sparse._sparsetools, , qutip.core.data.csr, scipy.sparse.csgraph._min_spanning_treescipy.ndimage._nd_imagescipy.optimize._bglu_dense, qutip.core.data.dia, numpy.random._common, , _csparsetools, , _ni_labelqutip.core.data.csr, , , qutip.core.data.dense, qutip.core.data.dianumpy.random._bounded_integers, qutip.core.data.addscipy.sparse.csgraph._flowscipy.ndimage._ni_label, , , qutip.core.data.dense, qutip.core.data.properties, numpy.random.bit_generator, , qutip.core.data.addnumpy.random._mt19937, numpy.random._bounded_integersscipy.sparse._csparsetools, scipy.optimize._lsapqutip.core.data.properties, , , qutip.core.data.mulnumpy.random._mt19937, qutip.core.data.mul, , , scipy.optimize._minpack2, qutip.core.data.matmul, numpy.random.mtrand, scipy.optimize._group_columns, qutip.core.data.inner, scipy.linalg._fblasscipy.sparse.csgraph._matchingnumpy.random.mtrandqutip.core.data.matmul, qutip.core.data.expect, numpy.random._philox, , scipy.optimize._directqutip.core.data.kron, , numpy.random._pcg64, qutip.core.data.pow, scipy.integrate._odepack, numpy.random._sfc64, , qutip.core.data.projectscipy.sparse.csgraph._reordering, , , numpy.random._philox, qutip.core.data.ptracescipy.optimize._trlib._trlib, scipy.integrate._quadpacknumpy.random._generator, qutip.core.data.norm, , numpy.random._pcg64scipy.linalg._flapack, qutip.core.data.permute, scipy.optimize._lbfgsbqutip.core.data.inner, scipy.linalg.cython_lapack, scipy.spatial._ckdtree, , _moduleTNCnumpy.random._sfc64, , , scipy.optimize._moduleTNC, , scipy._lib.messagestream, qutip.core.data.expectscipy.integrate._vodequtip.core.cy.coefficient, , numpy.random._generatorscipy.optimize._cobyla, scipy.linalg._cythonized_array_utils, qutip.core.cy._elementscipy.integrate._dop, qutip.core.data.kron, qut ...
# , , scipy.sparse.linalg._propack._dpropack, scipy.stats._boost.hypergeom_ufunc, , scipy.stats.binom_ufuncscipy.sparse.csgraph._tools, , scipy.stats._boost.binom_ufunc_ni_label, , scipy.stats.nbinom_ufunc, , scipy.stats.ncf_ufunc, , scipy.ndimage._ni_labelscipy.sparse.csgraph._shortest_path, scipy.stats._boost.ncf_ufuncscipy.fftpack.convolvescipy.stats._boost.nbinom_ufunc, , scipy.sparse.csgraph._traversalscipy.sparse.linalg._dsolve._superluscipy.optimize._minpack2, qutip.solver.sode.ssystem, , scipy.stats.hypergeom_ufunc, scipy.sparse.linalg._propack._cpropack, scipy.sparse.linalg._eigen.arpack._arpack, , scipy.sparse.csgraph._min_spanning_tree, , scipy.sparse.linalg._propack._spropackscipy.optimize._group_columns, , , scipy.sparse.linalg._propack._dpropackqutip.solver.sode._sode, scipy.sparse.linalg._propack._zpropack, scipy.sparse.linalg._propack._cpropack, scipy.optimize._trlib._trlib, scipy.stats._boost.hypergeom_ufunc, , scipy.sparse.csgraph._toolsqutip.piqs._piqsscipy.sparse.linalg._propack._zpropackscipy.stats.ncx2_ufunc, scipy.sparse.csgraph._shortest_path, scipy.sparse.csgraph._tools, scipy.optimize._lbfgsb, , scipy.sparse.csgraph._flow, , , scipy.sparse.csgraph._traversal, scipy.sparse.csgraph._matchingqutip._distributionsscipy.sparse.csgraph._shortest_path, scipy.sparse.csgraph._reorderingscipy.stats._boost.ncx2_ufunc, scipy.spatial._ckdtree, scipy.sparse.csgraph._min_spanning_treescipy.stats.ncf_ufunc, , scipy.sparse.csgraph._flowscipy._lib.messagestream, , scipy.sparse.csgraph._matchingscipy.spatial._qhull, , , , scipy.stats.nct_ufuncscipy.stats._boost.ncf_ufuncscipy.sparse.csgraph._reordering, scipy.stats._boost.nct_ufunc, _moduleTNC, scipy.sparse.csgraph._traversalscipy.spatial._voronoi, scipy.optimize._moduleTNC, scipy.stats.ncx2_ufunc, scipy.optimize._cobyla, , scipy.optimize._slsqp, scipy.spatial._ckdtree, scipy.sparse.csgraph._min_spanning_tree, scipy._lib.messagestream, scipy.spatial._distance_wrap, , , scipy.optimize._minpack (total: , scipy.stats.skewnorm_ufunc155)
# , scipy.stats._boost.skewnorm_ufuncscipy.sparse.csgraph._flow, scipy.optimize._lsq.givens_elimination, scipy.stats.invgauss_ufunc, scipy.stats._boost.invgauss_ufunc, scipy.optimize._zeros, , scipy.interpolate._fitpack, scipy.spatial._qhull, scipy.interpolate.dfitpackscipy.stats._boost.ncx2_ufunc, scipy.interpolate._bspl, scipy.sparse.csgraph._matchingscipy.spatial._hausdorff, scipy.spatial._voronoiscipy.optimize._highs.cython.src._highs_wrapper, scipy.optimize._highs._highs_wrapper, , , scipy.optimize._highs.cython.src._highs_constants, , , scipy.sparse.csgraph._reorderingscipy.optimize._highs._highs_constants, scipy.linalg._interpolative, scipy.spatial._ckdtreescipy.interpolate._ppolyscipy.stats.nct_ufunc, scipy.spatial._distance_wrap, scipy.special._ufuncs_cxx, scipy._lib.messagestream, scipy.optimize._bglu_densescipy.special._cdflib, scipy.interpolate.interpnd, scipy.special._ufuncs, scipy.stats._boost.nct_ufunc, , scipy.spatial._hausdorffscipy.special._specfun, scipy.stats.skewnorm_ufunc, , scipy.optimize._lsapscipy.stats._boost.skewnorm_ufunc, , , scipy.interpolate._rbfinterp_pythran, , , scipy.interpolate._rgi_cythonscipy.stats.invgauss_ufuncscipy.special._comb, , scipy.stats._biasedurnscipy.special._ufuncs_cxxscipy.optimize._directscipy.spatial._qhull, , scipy.stats._levy_stable.levystscipy.spatial._voronoi, , , scipy.stats._stats_pythran, scipy.spatial._distance_wrap, scipy._lib._uarray._uarray, , scipy.spatial._hausdorffscipy.special._cdflibscipy.stats._boost.invgauss_ufuncscipy.special._ellip_harm_2, scipy.stats._ansari_swilk_statistics, , scipy.integrate._odepack, scipy.special._ufuncs_cxx, scipy.interpolate._fitpack, scipy.special._ufuncsscipy.spatial.transform._rotation, scipy.special._cdflib, scipy.stats._sobol, scipy.ndimage._nd_image, , _ni_label, scipy.special._ufuncs, scipy.stats._qmc_cy, scipy.ndimage._ni_label, , , , scipy.optimize._minpack2scipy.integrate._quadpackscipy.stats._mvn, scipy.optimize._group_columnsscipy.special._specfun, , scipy.integrate._vodescipy.optimize._trlib._trlibscipy.interpolate.dfitpack, scipy.optimize._lbfgsb, , scipy.integrate._dop, _moduleTNC, scipy.integrate._lsoda, scipy.optimize._moduleTNCscipy.special._specfun, scipy.optimize._cobyla, scipy.interpolate._bspl, , scipy.special.cython_specialscipy.optimize._slsqp, , , , , , scipy.optimize._minpackscipy.special._combscipy.stats._stats, scipy.interpolate._ppolyscipy.special._ellip_harm_2, scipy.interpolate.interpnd, scipy.spatial.transform._rotation, scipy.interpolate._rbfinterp_pythranscipy.special._comb, , scipy.ndimage._nd_imagescipy.optimize._lsq.givens_elimination, scipy.optimize._zeros, , , scipy.stats._rcont.rcontscipy.stats.beta_ufunc, scipy.optimize._highs.cython.src._highs_wrapper, scipy.stats._unuran.unuran_wrapper, _ni_label, scipy.stats._boost.beta_ufuncscipy.special._ellip_harm_2, scipy.interpolate._rgi_cythonscipy.stats.binom_ufunc, scipy.ndimage._ni_label, , scipy.stats._boost.binom_ufuncscipy.stats._biasedurn, scipy.spatial.transform._rotation, , scipy.stats._levy_stable.levystscipy.stats.nbinom_ufunc, , , scipy.optimize._minpack2, scipy.ndimage._nd_image, , scipy.optimize._group_columnsscipy.stats._boost.nbinom_ufunc, scipy.stats._stats_pythran, , _ni_labelscipy.optimize._trlib._trlib, scipy.stats.hypergeom_ufunccython.cimports.libc.math, scipy.ndimage._ni_labelscipy.optimize._highs._highs_wrapper, scipy.stats._boost.hypergeom_ufunc, scipy.optimize._lbfgsb, , scipy.optimize._minpack2scipy.stats.ncf_ufunc, scipy._lib._uarray._uarray, , qutip.core.data.base, scipy.stats._boost.ncf_ufunc, scipy.optimize._group_columnsscipy.optimize._highs.cython.src._highs_constants, , , scipy.stats.ncx2_ufuncscipy.optimize._trlib._trlib, _moduleTNCscipy.optimize._highs._highs_constants, scipy.stats._boost.ncx2_ufunc, scipy.optimize._lbfgsb, , , scipy.linalg._interpolativescipy.stats.nct_ufunc, , scipy.optimize._bglu_dense, scipy.stats._ansari_swilk_statistics, , scipy.optimize._lsap, qutip.core.data.convertscipy.stats._sobol, , sci ...
# scipy.stats._boost.ncx2_ufunc
# , qutip.core.data.base, scipy.stats._levy_stable.levyst, scipy.stats._stats_pythranqutip.core.data.trace, scipy.stats.nct_ufunc, scipy._lib._uarray._uarray, scipy.stats._ansari_swilk_statistics, qutip.core.data.convert, scipy.stats._boost.nct_ufunc, scipy.stats._sobol, scipy.stats.skewnorm_ufunc, scipy.stats._qmc_cy, scipy.stats._boost.skewnorm_ufunc, scipy.stats._mvn, scipy.stats.invgauss_ufunc, qutip.core.data.dispatch, , scipy.stats._boost.invgauss_ufuncscipy.stats._rcont.rcont, scipy.interpolate._fitpack, scipy.stats._unuran.unuran_wrapper, qutip.core.data.adjoint, scipy.interpolate.dfitpack, scipy.interpolate._bspl, qutip.core.data.reshape, scipy.interpolate._ppoly, scipy.interpolate.interpnd, , scipy.interpolate._rbfinterp_pythran, cython.cimports.libc.mathqutip.core.data.trace, , qutip.core.data.tidyupscipy.interpolate._rgi_cython, qutip.core.data.base, qutip.core.data.csr, , scipy.stats._biasedurnqutip.core.data.convert, qutip.core.data.tidyup, , qutip.core.data.diaqutip.core.data.dispatch, scipy.stats._levy_stable.levyst, , qutip.core.data.adjointqutip.core.data.dense, scipy.stats._stats_pythran, qutip.core.data.add, , qutip.core.data.reshapescipy._lib._uarray._uarray, qutip.core.data.properties, qutip.core.data.trace, , qutip.core.data.tidyup, , qutip.core.data.mul, qutip.core.data.csr, qutip.core.data.matmulqutip.core.data.csr, qutip.core.data.dia, qutip.core.data.inner, qutip.core.data.densescipy.stats._ansari_swilk_statistics, qutip.core.data.expect, qutip.core.data.add, scipy.stats._sobol, , qutip.core.data.dia, scipy.stats._qmc_cyqutip.core.data.kron, qutip.core.data.properties, scipy.stats._mvn, qutip.core.data.pow, qutip.core.data.mul, qutip.core.data.project, scipy.stats._rcont.rcont, qutip.core.data.matmul, qutip.core.data.ptrace, scipy.stats._unuran.unuran_wrapper, , qutip.core.data.normqutip.core.data.dense, qutip.core.data.permute, , qutip.core.data.add, qutip.core.cy.coefficientcython.cimports.libc.math, qutip.core.cy._element, qutip.core.data.base, qutip.core.cy.qobjevo, qutip.core.data.properties, qutip.core.data.convert, qutip.core.data.mul, gmpy2.gmpy2, qutip.core.data.dispatch, qutip.core.data.matmul, qutip.core.data.adjoint, , qutip.core.data.innerqutip.core.data.reshape, qutip.core.data.inner, , qutip.core.data.expectqutip.core.data.trace, , , qutip.core.data.kronqutip.core.data.expect, qutip.core.data.tidyup, qutip.core.data.pow, qutip.core.data.csr, qutip.core.data.kron, qutip.core.data.project, qutip.core.data.dia, qutip.core.data.powqutip.core._brtools, qutip.core.data.ptrace, qutip.core.data.dense, qutip.core.data.project, qutip.core.data.norm, qutip.core.data.add, qutip.core.data.ptrace, qutip.core.data.permute, , , qutip.core.data.normqutip.core.cy.coefficient, qutip.core.data.properties, qutip.core.data.permute, qutip.core.cy._element, qutip.core._brtensorqutip.core.data.mul, qutip.core.cy.coefficient, qutip.core.cy.qobjevo, qutip.core.data.matmul, qutip.core.cy._element, , qutip.core.data.innerqutip.core.cy.qobjevo, , gmpy2.gmpy2qutip.core.data.expect, gmpy2.gmpy2, , qutip.core.data.kronqutip.solver.integrator.explicit_rk, qutip.core._brtools, qutip.core.data.pow, qutip.core._brtools, , qutip.core.data.project, qutip.core._brtensor, qutip.core.data.ptrace, qutip.solver.integrator.explicit_rk, , qutip.core.data.normqutip.core._brtensor, qutip.core.data.permute, , qutip.solver.cy.nm_mcsolvequtip.core.cy.coefficient, scipy.fftpack.convolve, qutip.core.cy._element, qutip.solver.sode.ssystem, qutip.core.cy.qobjevo, , qutip.solver.integrator.explicit_rkqutip.solver.sode._sode, gmpy2.gmpy2, , qutip.piqs._piqsqutip.solver.cy.nm_mcsolve, scipy.fftpack.convolve, , qutip.solver.sode.ssystemqutip.core._brtools, qutip.solver.sode._sodequtip.solver.cy.nm_mcsolve, qutip.piqs._piqs, qutip._distributions, qutip.core._brtensor, scipy.fftpack.convolve, qutip.solver.sode.ssystem, qutip.solver.integrator.explicit_rk, qutip.solver.sode._sode, qutip.piqs._piqs, qutip._distributions, qutip.solver.cy.nm_mcsolve,  ...
# , qutip.solver.sode.ssystem, , qutip.solver.sode._sodequtip._distributions (total: 155)
# , qutip.piqs._piqs (total: 155)
# , qutip._distributions (total: 155)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       4 for ramp_time in ramp_times:
#       5     for A in A_values:
# ----> 6         avg, std = compute_fidelity_drag(ramp_time, A)
#       7         results.append(avg)
#       8         std_errors.append(std)
#
# Cell In[4], line 48, in compute_fidelity_drag(ramp_time, A)
#      46 # Parallelize over all trajectories using joblib
#      47 from joblib import Parallel, delayed
# ---> 48 final_states = Parallel(n_jobs=-1)(delayed(run_single_trajectory)(traj_idx) for traj_idx in range(sim.num_realizations))
#      50 # Compute expectation values for each final state
#      51 values.append([qt.expect(projectors[idx], state) for state in final_states])
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/fluxonium/lib/python3.11/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/fluxonium/lib/python3.11/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/fluxonium/lib/python3.11/site-packages/joblib/parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
# Sweep ramp time for a specific A value
A_fixed = 5e-3 * 2 * np.pi
ramp_times = [40, 80, 120, 160, 210]

print(f"Sweeping ramp time for fixed A = {A_fixed/(2*np.pi):.3e}")
sweep_results = []
sweep_std_errors = []

for ramp_time in ramp_times:
    avg, std = compute_fidelity(ramp_time, A_fixed)
    sweep_results.append(avg)
    sweep_std_errors.append(std)
    print(f"Ramp time: {ramp_time:.1f} ns, Infidelity: {avg:.6e} ± {std:.6e}")

# Add sweep results to the main results
results.extend(sweep_results)
std_errors.extend(sweep_std_errors)

print(f"\nSweep completed. Added {len(sweep_results)} results to main results array.")
print(f"Total results: {len(results)}")
# Out:
# Sweeping ramp time for fixed A = 5.000e-03
# Ramp time: 40.0 ns, Infidelity: 1.246013e-02 ± 1.539566e-04
# Ramp time: 80.0 ns, Infidelity: 1.764777e-04 ± 6.408512e-06
# Ramp time: 120.0 ns, Infidelity: 8.271178e-05 ± 3.575090e-06
# Ramp time: 160.0 ns, Infidelity: 9.651991e-05 ± 4.707361e-06
# Ramp time: 210.0 ns, Infidelity: 1.043008e-04 ± 4.614505e-06
#
# Sweep completed. Added 5 results to main results array.
# Total results: 25

# %%
# Save plot data for easy export to other files
plot_data = {
    'ramp_times': ramp_times,
    'A_values': A_values,
    'A_values_normalized': [A/(2*np.pi) for A in A_values],
    'infidelity_matrix': infidelity_matrix,
    'std_error_matrix': std_error_matrix,
    'sweep_results': sweep_results,
    'sweep_std_errors': sweep_std_errors,
    'A_fixed': A_fixed,
    'A_fixed_normalized': A_fixed/(2*np.pi)
}

# Save data to numpy file
np.savez('preparation_fidelity_data.npz', **plot_data)
print("Plot data saved to 'preparation_fidelity_data.npz'")

# Create a figure for plotting infidelity vs ramp_time for different A values
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

# Set font sizes for paper-quality figure
plt.rcParams.update({
    'font.family': 'serif',
    'font.serif': ['Times New Roman', 'Times', 'DejaVu Serif'],
    'font.size': 14,
    'axes.titlesize': 14,
    'axes.labelsize': 14,
    'xtick.labelsize': 12,
    'ytick.labelsize': 12,
    'legend.fontsize': 12,
    'figure.titlesize': 14,
    'mathtext.fontset': 'stix'
})

# Plot infidelity for each A value
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
for i, A in enumerate(A_values):
    infidelity = infidelity_matrix[:, i]
    std_error = std_error_matrix[:, i]
    ax.errorbar(ramp_times, infidelity, yerr=std_error, fmt='o-', 
                label=f'A = {A/(2*np.pi):.1e}', linewidth=2, markersize=6, capsize=3,
                color=colors[i % len(colors)])
ax.errorbar(ramp_times, sweep_results, yerr=sweep_std_errors, fmt='o--', 
                label=f'A = {A/(2*np.pi):.1e}', linewidth=2, markersize=6, capsize=3,color=colors[2])
ax.set_xlabel('Ramp Time (ns)')
ax.set_ylabel('Infidelity')
ax.legend()
ax.grid(True, alpha=0.3)
ax.set_yscale('log')

plt.tight_layout()
# Save the plot in tight form as a PDF with the name 'preparation_fidelity.pdf'
plt.savefig('preparation_fidelity.pdf', bbox_inches='tight')
plt.show()
# Out:
# Plot data saved to 'preparation_fidelity_data.npz'

# %%
def compute_dephasing_rate(A):
    initial_state = []
    t_max = 100000
    num_realizations = 100
    S0 = 1e-5
    sample_rate = 1        # per ns
    sim = Simulation(A,initial_state, t_max,sample_rate, num_realizations,S0)

    # Define parameter ranges
    gamma = 1/(2e4)
    sds, sop, H_control, H0 = sim.operators()
    sim_time = 30000
    time_points = np.linspace(0, sim_time, 30000)
    floquet_states,sigmax,sigmas = sim.kick_and_sigmax(0)
    get_projector = sim.get_projector
    floquet_ground = floquet_states[:,0]
    floquet_excited = floquet_states[:,1]
    initial_state = qt.Qobj(floquet_excited)
    projectors = get_projector(floquet_states)

    L = np.sqrt(gamma) * qt.Qobj(sop)
    c_ops = [L]

    drive_term = lambda t, args: A * np.cos(sim.optimal_omega * t )
    H = [H0, [H_control, drive_term]]
    opts = {'nsteps': t_max, 'atol': 1e-13, 'rtol': 1e-13}
    result = qt.mesolve(H, initial_state, time_points, c_ops, options=opts)
    # Compute time-dependent projectors and expectation values
    avg_values = np.zeros(len(time_points))
    for j, t in enumerate(time_points):
        floquet_states, sigmax, sigmas = sim.kick_and_sigmax(t)
        projectors = get_projector(floquet_states)
        P00 = projectors[0]
        avg_values[j] = qt.expect(P00, result.states[j])
    def fit1(t, T1):
        return 1 - np.exp(-t / T1)
    from scipy.optimize import curve_fit
    popt, pcov = curve_fit(fit1, time_points, np.array(avg_values))
    T1_fitted = popt[0]

    initial_state = 1/np.sqrt(2)*(qt.Qobj(floquet_excited) + qt.Qobj(floquet_ground))
    result = qt.mesolve(H, initial_state, time_points, c_ops, options=opts)

    for j, t in enumerate(time_points):
        floquet_states, sigmax, sigmas = sim.kick_and_sigmax(t)
        projectors = get_projector(floquet_states)
        P00 = projectors[0]
        avg_values[j] = qt.expect(qt.Qobj(sigmax), result.states[j])
    def T2fit(t, T2):
        return np.exp(-t / T2) * np.cos(sim.sc.fit_omega * t)

    popt, pcov = curve_fit(T2fit, time_points, avg_values, p0=[1e6])
    T2_fit = popt[0]
    dephasing_rate1 = 1/T2_fit - 1/T1_fitted/2
    dephasing_rate2 =  gamma*(((2*A/(0.1*2*np.pi))**(2/3)/4)**2 + (0.01*(0.1*2*np.pi/(2*A))**(1/3))**2/2)
    return dephasing_rate1, dephasing_rate2

# %%
A_values = np.linspace(0.05e-3, 5e-3, 20) * 2 * np.pi
from joblib import Parallel, delayed

# Compute dephasing rates for all A values in parallel
dephasing_rates = Parallel(n_jobs=-1)(delayed(compute_dephasing_rate)(A) for A in A_values)

# Separate the two dephasing rates
dephasing_rates_numeric = [rate[0] for rate in dephasing_rates]
dephasing_rates_analytic = [rate[1] for rate in dephasing_rates]

# %%
import pickle

relaxation_data = {
    'A_values': A_values,
    'dephasing_rates_numeric': dephasing_rates_numeric,
    'dephasing_rates_analytic': dephasing_rates_analytic,
}
with open('relaxation_dephasing.pkl', 'wb') as f:
    pickle.dump(relaxation_data, f)
print("Data saved to relaxation_dephasing.pkl")
# Out:
# Data saved to relaxation_dephasing.pkl

# %%
# Plot dephasing rate vs A
plt.figure(figsize=(10, 6))
plt.plot(A_values / (2 * np.pi), dephasing_rates_numeric, 'bo-', linewidth=2, markersize=6, label='Numeric')
plt.plot(A_values / (2 * np.pi), dephasing_rates_analytic, 'ro-', linewidth=2, markersize=6, label='Analytic')
plt.xlabel('Drive Amplitude A (Hz)')
plt.ylabel('Dephasing Rate (Hz)')
plt.title('Dephasing Rate vs Drive Amplitude')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
A_values = np.linspace(0.003e-3, 0.03e-3, 20) * 2 * np.pi
from joblib import Parallel, delayed

# Compute dephasing rates for all A values in parallel
dephasing_rates = Parallel(n_jobs=-1)(delayed(compute_dephasing_rate)(A) for A in A_values)

# Separate the two dephasing rates
dephasing_rates_numeric = [rate[0] for rate in dephasing_rates]
dephasing_rates_analytic = [rate[1] for rate in dephasing_rates]
# Out:
# original_rate (omega_s) = 6.137458e+02, min_rate = 5.682992e-03
# optimal_omega_d = 6.159162 GHz, detuning = 0.0728 MHz
# original_rate (omega_s) = 1.516038e+03, min_rate = 1.156685e-03
# optimal_omega_d = 6.159232 GHz, detuning = 0.1433 MHz
# original_rate (omega_s) = 7.878208e+02, min_rate = 1.954852e-03
# optimal_omega_d = 6.159176 GHz, detuning = 0.0869 MHz
# original_rate (omega_s) = 1.331105e+03, min_rate = 2.660400e-03
# optimal_omega_d = 6.159218 GHz, detuning = 0.1291 MHz
# original_rate (omega_s) = 1.544262e+02, min_rate = 5.612414e-03
# optimal_omega_d = 6.159120 GHz, detuning = 0.0307 MHz
# original_rate (omega_s) = 4.465179e+02, min_rate = 2.042000e-03
# optimal_omega_d = 6.159148 GHz, detuning = 0.0587 MHz
# original_rate (omega_s) = 1.147661e+03, min_rate = 1.877396e-04
# optimal_omega_d = 6.159204 GHz, detuning = 0.1151 MHz
# original_rate (omega_s) = 2.906095e+02, min_rate = 9.928627e-04
# optimal_omega_d = 6.159134 GHz, detuning = 0.0446 MHz
# original_rate (omega_s) = 9.662722e+02, min_rate = 1.688015e-03
# optimal_omega_d = 6.159190 GHz, detuning = 0.1010 MHz
# original_rate (omega_s) = 1.702081e+03, min_rate = 4.094787e-04
# optimal_omega_d = 6.159246 GHz, detuning = 0.1573 MHz
# original_rate (omega_s) = 1.888974e+03, min_rate = 6.100365e-04
# optimal_omega_d = 6.159260 GHz, detuning = 0.1714 MHz
# original_rate (omega_s) = 3.020512e+03, min_rate = 2.073030e-03
# optimal_omega_d = 6.159344 GHz, detuning = 0.2554 MHz
# original_rate (omega_s) = 2.453119e+03, min_rate = 1.424382e-03
# optimal_omega_d = 6.159302 GHz, detuning = 0.2135 MHz
# original_rate (omega_s) = 2.641977e+03, min_rate = 1.741398e-04
# optimal_omega_d = 6.159316 GHz, detuning = 0.2274 MHz
# original_rate (omega_s) = 2.076529e+03, min_rate = 4.344116e-04
# optimal_omega_d = 6.159274 GHz, detuning = 0.1854 MHz
# original_rate (omega_s) = 3.210107e+03, min_rate = 5.933884e-04
# optimal_omega_d = 6.159358 GHz, detuning = 0.2693 MHz
# original_rate (omega_s) = 2.264611e+03, min_rate = 1.415785e-03
# optimal_omega_d = 6.159288 GHz, detuning = 0.1995 MHz
# original_rate (omega_s) = 2.831123e+03, min_rate = 1.373969e-03
# optimal_omega_d = 6.159330 GHz, detuning = 0.2414 MHz
# original_rate (omega_s) = 3.399877e+03, min_rate = 6.462244e-04
# optimal_omega_d = 6.159372 GHz, detuning = 0.2832 MHz
# original_rate (omega_s) = 3.589798e+03, min_rate = 3.430429e-04
# optimal_omega_d = 6.159386 GHz, detuning = 0.2970 MHz

# %%
dephasing_rates_numeric
# Out:
# [np.float64(2.0558598128959997e-07),
#  np.float64(2.1518684496701045e-07),
#  np.float64(2.1622995946583107e-07),
#  np.float64(2.155605361110568e-07),
#  np.float64(2.1399055183021605e-07),
#  np.float64(2.1208060171880525e-07),
#  np.float64(2.0999026582829861e-07),
#  np.float64(2.0783035603048582e-07),
#  np.float64(2.0550587874881976e-07),
#  np.float64(2.0382180564731774e-07),
#  np.float64(2.0159316871217913e-07),
#  np.float64(1.9932928174490538e-07),
#  np.float64(1.9713552114557644e-07),
#  np.float64(1.9499178640320486e-07),
#  np.float64(1.929426855601915e-07),
#  np.float64(1.9084436620295186e-07),
#  np.float64(1.8881924213174832e-07),
#  np.float64(1.8690343396833823e-07),
#  np.float64(1.8495848648293697e-07),
#  np.float64(1.8303877308320955e-07)]

# %%
plt.plot(A_values/2/np.pi,dephasing_rates_numeric)  

import pickle
data = {
    'A_values': A_values,
    'dephasing_rates_numeric': dephasing_rates_numeric,
}
with open('unselective_relaxation.pkl', 'wb') as f:
    pickle.dump(data, f)
print("Data saved to 'unselective_relaxation.pkl'")
# Out:
# Data saved to 'unselective_relaxation.pkl'

# %%
sim.sc.omega_s/2/np.pi
# Out:
# np.float64(6.15908888066734)
